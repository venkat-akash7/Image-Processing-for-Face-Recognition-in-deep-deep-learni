# %%
import cv2

# %%
img=cv2.imread('/content/Valentino_Rossi_2010_Qatar.jpg')

# %%
print(img)
# Out:
# [[[  6   9  23]
#   [  6   9  23]
#   [  6   9  23]
#   ...
#   [  8  10  21]
#   [  7   9  20]
#   [  7   9  20]]
#
#  [[  5   8  22]
#   [  5   8  22]
#   [  6   9  23]
#   ...
#   [  7   9  20]
#   [  7   9  20]
#   [  7   9  20]]
#
#  [[  6   9  23]
#   [  6   9  23]
#   [  6   9  23]
#   ...
#   [  8  10  21]
#   [  7   9  20]
#   [  7   9  20]]
#
#  ...
#
#  [[219 238 223]
#   [223 236 222]
#   [228 235 222]
#   ...
#   [ 60  17   0]
#   [ 58  18   0]
#   [ 58  18   0]]
#
#  [[224 238 226]
#   [227 237 225]
#   [233 234 224]
#   ...
#   [ 57  16   1]
#   [ 55  16   1]
#   [ 55  16   1]]
#
#  [[226 233 230]
#   [233 231 230]
#   [240 229 231]
#   ...
#   [ 55  16   1]
#   [ 55  16   2]
#   [ 55  16   2]]]

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=530x708>

# %%
img=cv2.imread('/content/Valentino_Rossi_2010_Qatar.jpg',0)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=530x708>

# %%
cv2.imwrite('VR46.jpg',img)
# Out:
# True

# %%
print(img.size)
# Out:
# 375240

# %%
print(img.shape)
# Out:
# (708, 530)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
image1=img[400:5000,400:5000]
from google.colab.patches import cv2_imshow
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=L size=130x308>

# %%
image2=cv2.rotate(image1,cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=L size=708x530>

# %%
img3=cv2.flip(img,0)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=L size=530x708>
